# %% [markdown]
# # Relational Database, Latihan SQL

# %% [markdown]
# ## Initiation
# ***

# %%
import pymysql
import pandas as pd

host = '127.0.0.1'
port = "3306"
user = 'root'
password = 'ugm2018'
database = 'classicmodels'

conn = pymysql.connect(
    host=host,
    port=int(port),
    user=user,
    passwd=password,
    db=database,
    charset='utf8mb4')

def run(sql):
    df = pd.read_sql_query(sql,conn)
    return df

# %% [markdown]
# ## Question
# ***

# %% [markdown]
# 1. Prepare a list of offices sorted by country, state, city.
# 2. How many employees are there in the company?
# 3. What is the total of payments received?
# 4. List the product lines that contain 'Cars'.
# 5. Report total payments for October 28, 2004.
# 6. Report those payments greater than \$100,000.
# 7. List the products in each product line.
# 8. How many products in each product line?
# 9. What is the minimum payment received?
# 10. List all payments greater than twice the average payment.
# 11. What is the average percentage markup of the MSRP on buyPrice?
# 12. How many distinct products does ClassicModels sell?
# 13. Report the name and city of customers who don't have sales representatives?
# 14. What are the names of executives with VP or Manager in their title? Use the CONCAT function to combine the employee's first name and last name into a single field for reporting.
# 15. Which orders have a value greater than $5,000?

# %% [markdown]
# ## Solution
# ***

# %% [markdown]
# ### 1. Prepare a list of offices sorted by country, state, city.

# %%
run('SELECT * FROM offices ORDER BY country, state, city')
# Out:
#   officeCode           city             phone              addressLine1  \
# 0          6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 1          4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 2          5          Tokyo   +81 33 224 5000               4-1 Kioicho
# 3          7         London  +44 20 7877 2041       25 Old Broad Street
# 4          1  San Francisco   +1 650 219 4782         100 Market Street
# 5          2         Boston   +1 215 837 0825          1550 Court Place
# 6          3            NYC   +1 212 555 3000      523 East 53rd Street
#
#   addressLine2       state    country postalCode territory
# 0     Floor #2        None  Australia   NSW 2010      APAC
# 1         None        None     France      75017      EMEA
# 2         None  Chiyoda-Ku      Japan   102-8578     Japan
# 3      Level 7        None         UK   EC2N 1HN      EMEA
# 4    Suite 300          CA        USA      94080        NA
# ...

# %% [markdown]
# ### 2. How many employees are there in the company?

# %%
run('SELECT COUNT(employeeNumber) as `Total Employee` FROM employees')
# Out:
#    Total Employee
# 0              23

# %% [markdown]
# ### 3. What is the total of payments received?

# %%
run('SELECT SUM(amount) as `Total Payment` FROM payments')
# Out:
#    Total Payment
# 0     8853839.23

# %% [markdown]
# ### 4. List the product lines that contain 'Cars'.

# %%
run('SELECT * FROM products WHERE productLine LIKE "%Cars"')
# Out:
#    productCode                                productName   productLine  \
# 0     S10_1949                   1952 Alpine Renault 1300  Classic Cars
# 1     S10_4757                        1972 Alfa Romeo GTA  Classic Cars
# 2     S10_4962                     1962 LanciaA Delta 16V  Classic Cars
# 3     S12_1099                          1968 Ford Mustang  Classic Cars
# 4     S12_1108                          2001 Ferrari Enzo  Classic Cars
# 5     S12_3148                         1969 Corvair Monza  Classic Cars
# 6     S12_3380                         1968 Dodge Charger  Classic Cars
# 7     S12_3891                           1969 Ford Falcon  Classic Cars
# 8     S12_3990                    1970 Plymouth Hemi Cuda  Classic Cars
# 9     S12_4675                         1969 Dodge Charger  Classic Cars
# 10    S18_1129                            1993 Mazda RX-7  Classic Cars
# 11    S18_1342                       1937 Lincoln Berline  Vintage Cars
# ...

# %% [markdown]
# ### 5. Report total payments for October 28, 2004.

# %%
run('SELECT SUM(amount) as `Total Payment` FROM payments WHERE paymentDate= "2004-10-28"')
# Out:
#    Total Payment
# 0       47411.33

# %% [markdown]
# ### 6. Report those payments greater than \$100,000.

# %%
run('SELECT * FROM payments WHERE amount > 100000')
# Out:
#    customerNumber checkNumber paymentDate     amount
# 0             124    AE215433  2005-03-05  101244.59
# 1             124    KI131716  2003-08-15  111654.40
# 2             141     ID10962  2004-12-31  116208.40
# 3             141    JE105477  2005-03-18  120166.58
# 4             148    KM172879  2003-12-26  105743.00

# %% [markdown]
# ### 7. List the products in each product line.

# %%
run('SELECT productName, productLine FROM products ORDER BY productLine')
# Out:
#                                      productName       productLine
# 0                       1952 Alpine Renault 1300      Classic Cars
# 1                            1972 Alfa Romeo GTA      Classic Cars
# 2                         1962 LanciaA Delta 16V      Classic Cars
# 3                              1968 Ford Mustang      Classic Cars
# 4                              2001 Ferrari Enzo      Classic Cars
# 5                             1969 Corvair Monza      Classic Cars
# 6                             1968 Dodge Charger      Classic Cars
# 7                               1969 Ford Falcon      Classic Cars
# 8                        1970 Plymouth Hemi Cuda      Classic Cars
# 9                             1969 Dodge Charger      Classic Cars
# 10                               1993 Mazda RX-7      Classic Cars
# 11                         1965 Aston Martin DB5      Classic Cars
# 12                   1948 Porsche 356-A Roadster      Classic Cars
# ...

# %% [markdown]
# ### 8. How many products in each product line?

# %%
run('SELECT productLine, COUNT(productName) as `Total` FROM products GROUP BY productLine')
# Out:
#         productLine  Total
# 0      Classic Cars     38
# 1       Motorcycles     13
# 2            Planes     12
# 3             Ships      9
# 4            Trains      3
# 5  Trucks and Buses     11
# 6      Vintage Cars     24

# %% [markdown]
# ### 9. What is the minimum payment received?

# %%
run('SELECT MIN(amount) as `Min Payment` FROM payments')
# Out:
#    Min Payment
# 0       615.45

# %% [markdown]
# ### 10. List all payments greater than twice the average payment.

# %%
run('SELECT * FROM payments WHERE amount > (SELECT 2*AVG(amount) FROM payments)')
# Out:
#     customerNumber checkNumber paymentDate     amount
# 0              114    MA765515  2004-12-15   82261.22
# 1              124    AE215433  2005-03-05  101244.59
# 2              124    BG255406  2004-08-28   85410.87
# 3              124     ET64396  2005-04-16   83598.04
# 4              124    KI131716  2003-08-15  111654.40
# 5              141     ID10962  2004-12-31  116208.40
# 6              141    IN446258  2005-03-25   65071.26
# 7              141    JE105477  2005-03-18  120166.58
# 8              148    KM172879  2003-12-26  105743.00
# 9              167    GN228846  2003-12-03   85024.46
# 10             239    NQ865547  2004-03-15   80375.24
# 11             321     DJ15149  2003-11-03   85559.12
# 12             323    AL493079  2005-05-23   75020.13

# %% [markdown]
# ### 11. What is the average percentage markup of the MSRP on buyPrice?

# %%
run('SELECT AVG(MSRP/buyPrice)*100 as `Average Markup %` from products')
# Out:
#    Average Markup %
# 0        188.702392

# %% [markdown]
# ### 12. How many distinct products does ClassicModels sell?

# %%
run('SELECT DISTINCT COUNT(productCode) AS `Total` FROM products WHERE productLine="Classic Cars"')
# Out:
#    Total
# 0     38

# %% [markdown]
# ### 13. Report the name and city of customers who don't have sales representatives?

# %%
run('SELECT customerName, city FROM customers WHERE salesRepEmployeeNumber IS NULL')
# Out:
#                       customerName              city
# 0               Havel & Zbyszek Co          Warszawa
# 1                Porto Imports Co.            Lisboa
# 2       Asian Shopping Network, Co         Singapore
# 3                  Natürlich Autos         Cunewalde
# 4                    ANG Resellers            Madrid
# 5         Messner Shopping Network         Frankfurt
# 6                Franken Gifts, Co           München
# 7                BG&E Collectables          Fribourg
# 8                 Schuyler Imports         Amsterdam
# 9                 Der Hund Imports            Berlin
# 10       Cramer Spezialitäten, Ltd       Brandenburg
# 11           Asian Treasures, Inc.              Cork
# 12            SAR Distributors, Co          Hatfield
# 13                 Kommission Auto           Münster
# 14          Lisboa Souveniers, Inc            Lisboa
# 15  Stuttgart Collectable Exchange         Stuttgart
# 16        Feuer Online Stores, Inc           Leipzig
# ...

# %% [markdown]
# ### 14. What are the names of executives with VP or Manager in their title? Use the CONCAT function to combine the employee's first name and last name into a single field for reporting.

# %%
run('SELECT CONCAT(firstName, " ", lastName) as `name`, jobTitle FROM employees WHERE jobTitle LIKE "%VP%" OR jobTitle LIKE "%Manager%"')
# Out:
#                 name              jobTitle
# 0     Mary Patterson              VP Sales
# 1      Jeff Firrelli          VP Marketing
# 2  William Patterson  Sales Manager (APAC)
# 3      Gerard Bondur   Sale Manager (EMEA)
# 4        Anthony Bow    Sales Manager (NA)

# %% [markdown]
# ### 15. Which orders have a value greater than $5,000?

# %%
run("""
SELECT orderNumber, SUM(quantityOrdered*priceEach) as `value`
FROM orderdetails GROUP by orderNumber
HAVING `value` > 5000
    """)
# Out:
#      orderNumber     value
# 0          10100  10223.83
# 1          10101  10549.01
# 2          10102   5494.78
# 3          10103  50218.95
# 4          10104  40206.20
# 5          10105  53959.21
# 6          10106  52151.81
# 7          10107  22292.62
# 8          10108  51001.22
# 9          10109  25833.14
# 10         10110  48425.69
# 11         10111  16537.85
# 12         10112   7674.94
# 13         10113  11044.30
# 14         10114  33383.14
# 15         10115  21665.98
# 16         10117  44380.15
# 17         10119  35826.33
# 18         10120  45864.03
# 19         10121  16700.47
# 20         10122  50824.66
# 21         10123  14571.44
# 22         10124  32641.98
# 23         10125   7565.08
# 24         10126  57131.92
# 25         10127  58841.35
# 26         10128  13884.99
# 27         10129  29429.14
# 28         10130   6036.96
# 29         10131  17032.29
# ..           ...       ...
# 273        10394  18102.74
# 274        10395  17928.09
# ...
