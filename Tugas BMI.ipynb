# %% [markdown]
# ## Calculating Body Mass Index (BMI) Problem
#
# Python challenge of Calculating Body Mass Index (BMI)
# **by Bakhtiar Amaludin**

# %%
categories = ['Very severely underweight',
              'Severely underweight',
              'Underweight',
              'Normal (healthy weight)',
              'Overweight',
              'Moderately obese',
              'Severely obese',
              'Very severely obese']

# main function, input : Weight (kg) and Height (cm)
def calculate_bmi(weight, height):
    bmi = weight / (height/100) ** 2
    if bmi < 15:
        cat_num = 0
    elif 15 < bmi < 16:
        cat_num = 1
    elif 16 < bmi < 18.5:
        cat_num = 2
    elif 18.5 < bmi < 25:
        cat_num = 3
    elif 25 < bmi < 30:
        cat_num = 4
    elif 30 < bmi < 35:
        cat_num = 5
    elif 35 < bmi < 40:
        cat_num = 6
    else: cat_num = 7

    return round(bmi, 2), categories[cat_num]


# get input from user
print("Welcome to BMI Calculator")

input_weight = int(input('Please input Your Weight in Kg :'), 0)
input_height = int(input('Please input Your Height in cm : '), 0)

# calculate BMI
result_bmi = calculate_bmi(input_weight, input_height)

# print result
print("=======================================")
print("=========== BMI Calculation ===========")
print("=======================================")
print("Weight   :", input_weight)
print("Height   :", input_height)
print("BMI      :", result_bmi[0])
print("Category :", result_bmi[1])
# Out:
# Welcome to BMI Calculator
# Please input Your Weight in Kg : 56
# Please input Your Height in cm :  165
# =======================================
# =========== BMI Calculation ===========
# =======================================
# Weight   : 56
# Height   : 165
# BMI      : 20.57
# Category : Normal (healthy weight)
